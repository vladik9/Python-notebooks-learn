# %% [markdown]
# Existing DataTypes in Python

# %% [markdown]
# ![image.1png](attachment:5ec6c5d8-7382-4708-9b94-340cdf6b46a0.png)

# %% [markdown]
# Numbers in Python (integers and floating point)

# %%
2+2
# Out:
# 4

# %%
3.2+4.2
# Out:
# 7.4

# %% [markdown]
# Modules

# %% [markdown]
# 50%2

# %%
2 ** 3
# Out:
# 8

# %%
(20-1)+23*23
# Out:
# 548

# %% [markdown]
# Variable assigments:

# %% [markdown]
# ![image.png](attachment:aa32351b-ce0d-4436-9106-385fda19d304.png)

# %% [markdown]
# ![image.png](attachment:a63e9006-60e1-480e-96b8-5211237d296d.png)

# %% [markdown]
# Checking types of vatriables in Python we can use type() method from standard Python library

# %%
a = "jonny"
type(a)
# Out:
# str

# %%
print(a)
# Out:
# jonny

# %%
a = "Mia"
print(a)
# Out:
# Mia

# %%
a =10
type(a)
# Out:
# int

# %%
print(a)
# Out:
# 10

# %%
a = 33.4
type(a)
# Out:
# float

# %% [markdown]
# Strings

# %% [markdown]
# ![image.png](attachment:31499b42-168a-4019-9f2b-5b75f7821889.png)

# %% [markdown]
# Python Strings are ArraysS of chars

# %% [markdown]
# String slicing
# [start:stop:step]

# %% [markdown]
# ![image.png](attachment:66efc597-2117-4360-9e1f-97076eaec4d5.png)

# %% [markdown]
# Mixing a string

# %%
"I am in a 'park "
# Out:
# "I am in a 'park "

# %% [markdown]
# Checking Length of the string

# %%
len("my name is jo")
# Out:
# 13

# %%
string = 'amareta'
string[3]
# Out:
# 'r'

# %%
string[-2]
# Out:
# 't'

# %%
string[1:5]
# Out:
# 'mare'

# %%
string[2:]
# Out:
# 'areta'

# %%
string[:3]
# Out:
# 'ama'

# %% [markdown]
# String steps will not include the limist, or will start with the step
